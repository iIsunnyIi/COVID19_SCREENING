# %% [markdown]
# <a href="https://colab.research.google.com/github/iIsunnyIi/COVID19_SCREENING/blob/main/Notebook_Updated_Version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Covid-19 Diagnoise based on Chest x-ray

# %%
# !pip install tensorflow-gpu==2.0.
# !pip install opencv-python==4.4.0.46
# !pip install numpy==1.16.5
# !pip install Pillow==5.3.0
# !pip install pandas 1.2.0
# !pip install Keras==2.3.1
# Out:
# Requirement already satisfied: tensorflow-gpu==2.0. in /usr/local/lib/python3.6/dist-packages (2.0.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.) (1.16.5)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.) (1.15.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.) (3.12.4)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.) (0.8.1)
# Requirement already satisfied: tensorboard<2.1.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.) (2.0.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.) (1.12.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.) (1.1.2)
# Requirement already satisfied: tensorflow-estimator<2.1.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.) (2.0.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.) (1.32.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.) (0.10.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.) (0.36.2)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.) (1.0.8)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==2.0.) (0.2.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==2.0.) (51.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.) (3.3.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.) (2.23.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.) (1.17.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.) (0.4.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow-gpu==2.0.) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.) (3.3.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.) (2.10)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.) (4.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.) (4.6)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.) (1.3.0)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.) (3.4.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow-gpu==2.0.) (3.1.0)
# Requirement already satisfied: opencv-python==4.4.0.46 in /usr/local/lib/python3.6/dist-packages (4.4.0.46)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python==4.4.0.46) (1.16.5)
# Requirement already satisfied: numpy==1.16.5 in /usr/local/lib/python3.6/dist-packages (1.16.5)
# Requirement already satisfied: Pillow==5.3.0 in /usr/local/lib/python3.6/dist-packages (5.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (1.1.5)
# ERROR: Could not find a version that satisfies the requirement 1.2.0 (from versions: none)
# ERROR: No matching distribution found for 1.2.0
# Requirement already satisfied: Keras==2.3.1 in /usr/local/lib/python3.6/dist-packages (2.3.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from Keras==2.3.1) (1.15.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras==2.3.1) (3.13)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from Keras==2.3.1) (1.1.2)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras==2.3.1) (1.4.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from Keras==2.3.1) (1.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras==2.3.1) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from Keras==2.3.1) (1.16.5)

# %%
pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# absl-py                       0.10.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.1.0
# argon2-cffi                   20.1.0
# asgiref                       3.3.1
# astor                         0.8.1
# astropy                       4.1
# astunparse                    1.6.3
# async-generator               1.10
# atari-py                      0.2.6
# atomicwrites                  1.4.0
# attrs                         20.3.0
# audioread                     2.1.9
# autograd                      1.3
# Babel                         2.9.0
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        3.2.1
# blis                          0.4.1
# bokeh                         2.1.1
# Bottleneck                    1.3.2
# branca                        0.4.1
# bs4                           0.0.1
# CacheControl                  0.12.6
# cachetools                    4.2.0
# catalogue                     1.0.0
# certifi                       2020.12.5
# cffi                          1.14.4
# chainer                       7.4.0
# chardet                       3.0.4
# click                         7.1.2
# cloudpickle                   1.3.0
# cmake                         3.12.0
# cmdstanpy                     0.9.5
# colorlover                    0.3.0
# community                     1.0.0b1
# contextlib2                   0.5.5
# convertdate                   2.2.0
# coverage                      3.7.1
# coveralls                     0.5
# crcmod                        1.7
# cufflinks                     0.17.3
# cupy-cuda101                  7.4.0
# cvxopt                        1.2.5
# cvxpy                         1.0.31
# cycler                        0.10.0
# cymem                         2.0.5
# Cython                        0.29.21
# daft                          0.0.4
# dask                          2.12.0
# dataclasses                   0.8
# datascience                   0.10.6
# debugpy                       1.0.0
# decorator                     4.4.2
# defusedxml                    0.6.0
# descartes                     1.1.0
# dill                          0.3.3
# distributed                   1.25.3
# Django                        3.1.4
# dlib                          19.18.0
# dm-tree                       0.1.5
# docopt                        0.6.2
# docutils                      0.16
# dopamine-rl                   1.0.5
# earthengine-api               0.1.238
# easydict                      1.9
# ecos                          2.0.7.post1
# editdistance                  0.5.3
# en-core-web-sm                2.2.5
# entrypoints                   0.3
# ephem                         3.7.7.1
# et-xmlfile                    1.0.1
# fa2                           0.3.5
# fancyimpute                   0.4.3
# fastai                        1.0.61
# fastdtw                       0.3.4
# fastprogress                  1.0.0
# fastrlock                     0.5
# fbprophet                     0.7.1
# feather-format                0.4.1
# filelock                      3.0.12
# firebase-admin                4.4.0
# fix-yahoo-finance             0.0.22
# Flask                         1.1.2
# flatbuffers                   1.12
# folium                        0.8.3
# future                        0.16.0
# gast                          0.2.2
# GDAL                          2.2.2
# gdown                         3.6.4
# gensim                        3.6.0
# geographiclib                 1.50
# geopy                         1.17.0
# gin-config                    0.4.0
# glob2                         0.7
# google                        2.0.3
# google-api-core               1.16.0
# google-api-python-client      1.7.12
# google-auth                   1.17.2
# google-auth-httplib2          0.0.4
# google-auth-oauthlib          0.4.2
# google-cloud-bigquery         1.21.0
# google-cloud-bigquery-storage 1.1.0
# google-cloud-core             1.0.3
# google-cloud-datastore        1.8.0
# google-cloud-firestore        1.7.0
# google-cloud-language         1.2.0
# google-cloud-storage          1.18.1
# google-cloud-translate        1.5.0
# google-colab                  1.0.0
# google-pasta                  0.2.0
# google-resumable-media        0.4.1
# googleapis-common-protos      1.52.0
# googledrivedownloader         0.4
# graphviz                      0.10.1
# grpcio                        1.32.0
# gspread                       3.0.1
# gspread-dataframe             3.0.8
# gym                           0.17.3
# h5py                          2.10.0
# HeapDict                      1.0.1
# holidays                      0.10.4
# holoviews                     1.13.5
# html5lib                      1.0.1
# httpimport                    0.5.18
# httplib2                      0.17.4
# httplib2shim                  0.0.3
# humanize                      0.5.1
# hyperopt                      0.1.2
# ideep4py                      2.0.0.post3
# idna                          2.10
# image                         1.5.33
# imageio                       2.4.1
# imagesize                     1.2.0
# imbalanced-learn              0.4.3
# imblearn                      0.0
# imgaug                        0.2.9
# importlib-metadata            3.3.0
# importlib-resources           3.3.0
# imutils                       0.5.3
# inflect                       2.1.0
# iniconfig                     1.1.1
# intel-openmp                  2021.1.1
# intervaltree                  2.1.0
# ipykernel                     4.10.1
# ipython                       5.5.0
# ipython-genutils              0.2.0
# ipython-sql                   0.3.9
# ipywidgets                    7.5.1
# itsdangerous                  1.1.0
# jax                           0.2.7
# jaxlib                        0.1.57+cuda101
# jdcal                         1.4.1
# jedi                          0.17.2
# jieba                         0.42.1
# Jinja2                        2.11.2
# joblib                        1.0.0
# jpeg4py                       0.1.4
# jsonschema                    2.6.0
# jupyter                       1.0.0
# jupyter-client                5.3.5
# jupyter-console               5.2.0
# jupyter-core                  4.7.0
# jupyterlab-pygments           0.1.2
# kaggle                        1.5.10
# kapre                         0.1.3.1
# Keras                         2.3.1
# Keras-Applications            1.0.8
# Keras-Preprocessing           1.1.2
# keras-vis                     0.4.1
# kiwisolver                    1.3.1
# knnimpute                     0.1.0
# korean-lunar-calendar         0.2.1
# librosa                       0.6.3
# lightgbm                      2.2.3
# llvmlite                      0.31.0
# lmdb                          0.99
# lucid                         0.3.8
# LunarCalendar                 0.0.9
# lxml                          4.2.6
# Markdown                      3.3.3
# MarkupSafe                    1.1.1
# matplotlib                    3.2.2
# matplotlib-venn               0.11.6
# missingno                     0.4.2
# mistune                       0.8.4
# mizani                        0.6.0
# mkl                           2019.0
# mlxtend                       0.14.0
# more-itertools                8.6.0
# moviepy                       0.2.3.5
# mpmath                        1.1.0
# msgpack                       1.0.1
# multiprocess                  0.70.11.1
# multitasking                  0.0.9
# murmurhash                    1.0.5
# music21                       5.5.0
# natsort                       5.5.0
# nbclient                      0.5.1
# nbconvert                     5.6.1
# nbformat                      5.0.8
# nest-asyncio                  1.4.3
# networkx                      2.5
# nibabel                       3.0.2
# nltk                          3.2.5
# notebook                      5.3.1
# np-utils                      0.5.12.1
# numba                         0.48.0
# numexpr                       2.7.1
# numpy                         1.16.5
# nvidia-ml-py3                 7.352.0
# oauth2client                  4.1.3
# oauthlib                      3.1.0
# okgrade                       0.4.3
# opencv-contrib-python         4.1.2.30
# opencv-python                 4.4.0.46
# openpyxl                      2.5.9
# opt-einsum                    3.3.0
# osqp                          0.6.1
# packaging                     20.8
# palettable                    3.3.0
# pandas                        1.1.5
# pandas-datareader             0.9.0
# pandas-gbq                    0.13.3
# pandas-profiling              1.4.1
# pandocfilters                 1.4.3
# panel                         0.9.7
# param                         1.10.0
# parso                         0.7.1
# pathlib                       1.0.1
# patsy                         0.5.1
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        5.3.0
# pip                           19.3.1
# pip-tools                     4.5.1
# plac                          1.1.3
# plotly                        4.4.1
# plotnine                      0.6.0
# pluggy                        0.7.1
# portpicker                    1.3.1
# prefetch-generator            1.0.1
# preshed                       3.0.5
# prettytable                   2.0.0
# progressbar2                  3.38.0
# prometheus-client             0.9.0
# promise                       2.3
# prompt-toolkit                1.0.18
# protobuf                      3.12.4
# psutil                        5.4.8
# psycopg2                      2.7.6.1
# ptyprocess                    0.6.0
# py                            1.10.0
# pyarrow                       0.14.1
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycocotools                   2.0.2
# pycparser                     2.20
# pyct                          0.4.8
# pydata-google-auth            1.1.0
# pydot                         1.3.0
# pydot-ng                      2.0.0
# pydotplus                     2.0.2
# PyDrive                       1.3.1
# pyemd                         0.5.1
# pyglet                        1.5.0
# Pygments                      2.6.1
# pygobject                     3.26.1
# pymc3                         3.7
# PyMeeus                       0.3.7
# pymongo                       3.11.2
# pymystem3                     0.2.0
# PyOpenGL                      3.1.5
# pyparsing                     2.4.7
# pyrsistent                    0.17.3
# pysndfile                     1.3.8
# PySocks                       1.7.1
# pystan                        2.19.1.1
# pytest                        3.6.4
# python-apt                    1.6.5+ubuntu0.4
# python-chess                  0.23.11
# python-dateutil               2.8.1
# python-louvain                0.14
# python-slugify                4.0.1
# python-utils                  2.4.0
# pytz                          2018.9
# pyviz-comms                   0.7.6
# PyWavelets                    1.1.1
# PyYAML                        3.13
# pyzmq                         20.0.0
# qtconsole                     5.0.1
# QtPy                          1.9.0
# regex                         2019.12.20
# requests                      2.23.0
# requests-oauthlib             1.3.0
# resampy                       0.2.2
# retrying                      1.3.3
# rpy2                          3.2.7
# rsa                           4.6
# scikit-image                  0.16.2
# scikit-learn                  0.22.2.post1
# scipy                         1.4.1
# screen-resolution-extra       0.0.0
# scs                           2.1.2
# seaborn                       0.11.0
# Send2Trash                    1.5.0
# setuptools                    51.0.0
# setuptools-git                1.2
# Shapely                       1.7.1
# simplegeneric                 0.8.1
# six                           1.15.0
# sklearn                       0.0
# sklearn-pandas                1.8.0
# smart-open                    4.0.1
# snowballstemmer               2.0.0
# sortedcontainers              2.3.0
# spacy                         2.2.4
# Sphinx                        1.8.5
# sphinxcontrib-serializinghtml 1.1.4
# sphinxcontrib-websupport      1.2.4
# SQLAlchemy                    1.3.20
# sqlparse                      0.4.1
# srsly                         1.0.5
# statsmodels                   0.10.2
# sympy                         1.1.1
# tables                        3.4.4
# tabulate                      0.8.7
# tblib                         1.7.0
# tensorboard                   2.0.2
# tensorboard-plugin-wit        1.7.0
# tensorboardcolab              0.0.22
# tensorflow                    2.4.0
# tensorflow-addons             0.8.3
# tensorflow-datasets           4.0.1
# tensorflow-estimator          2.0.1
# tensorflow-gcs-config         2.4.0
# tensorflow-gpu                2.0.0
# tensorflow-hub                0.10.0
# tensorflow-metadata           0.26.0
# tensorflow-privacy            0.2.2
# tensorflow-probability        0.11.0
# termcolor                     1.1.0
# terminado                     0.9.1
# testpath                      0.4.4
# text-unidecode                1.3
# textblob                      0.15.3
# textgenrnn                    1.4.1
# Theano                        1.0.5
# thinc                         7.4.0
# tifffile                      2020.9.3
# toml                          0.10.2
# toolz                         0.11.1
# torch                         1.7.0+cu101
# torchsummary                  1.5.1
# torchtext                     0.3.1
# torchvision                   0.8.1+cu101
# tornado                       5.1.1
# tqdm                          4.41.1
# traitlets                     4.3.3
# tweepy                        3.6.0
# typeguard                     2.7.1
# typing-extensions             3.7.4.3
# tzlocal                       1.5.1
# umap-learn                    0.4.6
# uritemplate                   3.0.1
# urllib3                       1.24.3
# vega-datasets                 0.9.0
# wasabi                        0.8.0
# wcwidth                       0.2.5
# webencodings                  0.5.1
# Werkzeug                      1.0.1
# wheel                         0.36.2
# widgetsnbextension            3.5.1
# wordcloud                     1.5.0
# wrapt                         1.12.1
# xarray                        0.15.1
# xgboost                       0.90
# xkit                          0.0.0
# xlrd                          1.1.0
# xlwt                          1.3.0
# yellowbrick                   0.9.1
# zict                          2.0.0
# zipp                          3.4.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # DesNet with CNN

# %% [markdown]
# Importing the Packages

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import os
for dirname, _, filenames in os.walk('/content/drive/MyDrive/covid/Data_test'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/drive/MyDrive/covid/Data_test/train/PNEUMONIA/PNEUMONIA(100).jpg
# /content/drive/MyDrive/covid/Data_test/train/PNEUMONIA/PNEUMONIA(1000).jpg
# /content/drive/MyDrive/covid/Data_test/train/PNEUMONIA/PNEUMONIA(10).jpg
# /content/drive/MyDrive/covid/Data_test/train/PNEUMONIA/PNEUMONIA(0).jpg
# /content/drive/MyDrive/covid/Data_test/train/PNEUMONIA/PNEUMONIA(1).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(1025).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(1022).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(1023).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(1020).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(1021).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(1019).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(1018).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(102).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(1017).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(103).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(1035).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(1037).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(1030).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(1036).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(1038).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(1031).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(1032).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(1029).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(1028).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(1026).jpg
# /content/drive/MyDrive/covid/Data_test/train/NORMAL/NORMAL(1027).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(104).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(108).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(0).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(109).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(103).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(12).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(100).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(1).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(10).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(11).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(113).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(114).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(137).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(135).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(117).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(134).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(110).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(116).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(115).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(112).jpg
# /content/drive/MyDrive/covid/Data_test/train/COVID19/COVID19(111).jpg
# /content/drive/MyDrive/covid/Data_test/test/PNEUMONIA/PNEUMONIA(3422).jpg
# /content/drive/MyDrive/covid/Data_test/test/PNEUMONIA/PNEUMONIA(3418).jpg
# /content/drive/MyDrive/covid/Data_test/test/PNEUMONIA/PNEUMONIA(3421).jpg
# /content/drive/MyDrive/covid/Data_test/test/PNEUMONIA/PNEUMONIA(3420).jpg
# /content/drive/MyDrive/covid/Data_test/test/PNEUMONIA/PNEUMONIA(3419).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1277).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1276).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1274).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1273).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1270).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1272).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1267).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1268).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1266).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1278).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1288).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1287).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1286).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1285).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1284).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1283).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1282).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1281).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1280).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1279).jpg
# /content/drive/MyDrive/covid/Data_test/test/NORMAL/NORMAL(1289).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(463).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(464).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(465).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(468).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(466).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(538).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(539).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(537).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(532).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(529).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(530).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(527).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(528).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(526).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(511).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(506).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(507).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(505).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(469).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(502).jpg
# /content/drive/MyDrive/covid/Data_test/test/COVID19/COVID19(546).jpg

# %%
import cv2                 
import numpy as np         
import os                  
from random import shuffle
import tensorflow as tf 
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import glob as gb
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Exploration of Dataset

# %%
#read DataSet
TrainImage="/content/drive/MyDrive/covid/Data_test/train/"
TestImage="/content/drive/MyDrive/covid/Data_test/test/"

print(TrainImage)
print(TestImage)
# Out:
# /content/drive/MyDrive/covid/Data_test/train/
# /content/drive/MyDrive/covid/Data_test/test/

# %%
#to get all image names in train file
Pneumonaimages = os.listdir(TrainImage + "/PNEUMONIA")
Normalimages = os.listdir(TrainImage + "/NORMAL")
COVID19images = os.listdir(TrainImage + "/COVID19")

# %%
#plot to show the size of some image
#plot PNEUMONIA
#plt.figure(figsize=(20,10))
#for i in range(6):
    #plt.subplot(3, 3, i + 1)
    #plt.imshow(plt.imread(os.path.join(TrianImage + "/PNEUMONIA",Pneumonaimages[i])),cmap='gray')
  #  plt.title("PNEUMONIA")
    
#plt.show()
#plot NORMAL
plt.figure(figsize=(20,10))
for i in range(6):
    plt.subplot(3, 3, i + 1)
    plt.imshow(plt.imread(os.path.join(TrainImage + "/NORMAL",Normalimages[i])),cmap='gray')
    plt.title("NORMAL")

plt.show()
#plot 
plt.figure(figsize=(20,10))
for i in range(6):
    plt.subplot(3, 3, i + 1)
    plt.imshow(plt.imread(os.path.join(TrainImage + "/COVID19",COVID19images[i])),cmap='gray')
    plt.title("COVID19")

# %% [markdown]
# Feature Extraction

# %%
train_datagen = ImageDataGenerator(
      samplewise_center=True,
      samplewise_std_normalization= True,
      width_shift_range=0.2,
      height_shift_range=0.2,
      shear_range=0.2,
      zoom_range=0.2,
      fill_mode='nearest'
                                  )

# NOTE: YOU MUST USE A BATCH SIZE OF 10 (batch_size=10) FOR THE 
# TRAIN GENERATOR.
train_generator =train_datagen.flow_from_directory(
     TrainImage,
     batch_size= 256,
     shuffle=shuffle,
     target_size=(300, 300)

)

test_generator =train_datagen.flow_from_directory(
     TestImage,
     batch_size= 50,
     shuffle=shuffle,
     target_size=(300, 300)

)
# Out:
# Found 47 images belonging to 3 classes.
# Found 47 images belonging to 3 classes.

# %%
trainShape=train_generator.__getitem__(0)[0].shape
testShape=test_generator.__getitem__(0)[0].shape

# %%
#Shape of Data
print("Train Shape \n",trainShape)
print("Test Shape \n",testShape)
# Out:
# Train Shape
#  (47, 300, 300, 3)
# Test Shape
#  (47, 300, 300, 3)

# %%
Labels={'NORMAL':0,'COVID19':1,'PNEUMONIA':2}

# convert label to code
def getCode(label):
    return Labels[label]


# convert code to label 
def getLabel(n):
    for x,c in Labels.items():
        if n==c:
            return x
        
        
        
#Test        
print(getCode('COVID19'))
print(getLabel(1))
# Out:
# 1
# COVID19

# %%
plt.figure(figsize=(20,10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(train_generator.__getitem__(0)[0][i])
    plt.title(getLabel(np.argmax(train_generator.__getitem__(0)[1][i])) )
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Data Splitting for DesNet Model

# %%
import glob as gb
import cv2  
sizeImage=300 # to resize the all image as same size

#to read all images from directory
def getData(Dir,sizeImage):
    X=[]
    y=[]
    for folder in  os.listdir(Dir) : #to get the file name 
        files = gb.glob(pathname= str( Dir  +"/" +folder+ '//*.jpg' )) # to get the images
        for file in files:
                picture=cv2.imread(file) #  or plt.imread(file)
                imageArray=cv2.resize(picture,(sizeImage,sizeImage))
                X.append(list(imageArray))
                y.append(getCode(folder))
    X=np.array(X)
    y=np.array(y)
    return X,y

# %%
#get train data
X_train, y_train = getData(TrainImage,sizeImage)
# get test data
X_test , y_test = getData(TestImage,sizeImage)

# %%
print("X_train Shape",X_train.shape)
print("X_test Shape ",X_test.shape)
# Out:
# X_train Shape (47, 300, 300, 3)
# X_test Shape  (47, 300, 300, 3)

# %%
# #Convert y_train to categorical
y_train=to_categorical(y_train,3)
print("y_train ",y_train.shape)
#Convert y_train to categorical
y_test=to_categorical(y_test,3)
print("y_test ",y_test.shape)
# Out:
# y_train  (47, 3)
# y_test  (47, 3)

# %% [markdown]
# Loading Pre-trained Weigh Model

# %%
#load weight
Network_Weight="/content/drive/MyDrive/covid/Model/DenseNet-BC-169-32-no-top.h5"
print(Network_Weight)
# Out:
# /content/drive/MyDrive/covid/Model/DenseNet-BC-169-32-no-top.h5

# %% [markdown]
# Model Building for DesNet

# %%
from tensorflow.keras.applications.densenet import DenseNet169
pre_trained_model = DenseNet169(input_shape = (sizeImage, sizeImage, 3), 
                                include_top = False, 
                                weights = None)
pre_trained_model.load_weights(Network_Weight)
for layer in pre_trained_model.layers:
    layer.trainable = False  #to make the layers to Freeze Weights
pre_trained_model.summary()
# Out:
# Model: "densenet169"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 306, 306, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 150, 150, 64) 9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 150, 150, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 150, 150, 64) 0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 152, 152, 64) 0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 75, 75, 64)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 75, 75, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, 75, 75, 64)   0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 75, 75, 128)  8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 75, 75, 128)  512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 75, 75, 128)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 75, 75, 32)   36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 75, 75, 96)   0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, 75, 75, 96)   384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, 75, 75, 96)   0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 75, 75, 128)  12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 75, 75, 128)  512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 75, 75, 128)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 75, 75, 32)   36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 75, 75, 128)  0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, 75, 75, 128)  512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, 75, 75, 128)  0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 75, 75, 128)  16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 75, 75, 128)  512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 75, 75, 128)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 75, 75, 32)   36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 75, 75, 160)  0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, 75, 75, 160)  640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, 75, 75, 160)  0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 75, 75, 128)  20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 75, 75, 128)  512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 75, 75, 128)  0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 75, 75, 32)   36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 75, 75, 192)  0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, 75, 75, 192)  768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, 75, 75, 192)  0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 75, 75, 128)  24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, 75, 75, 128)  512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 75, 75, 128)  0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 75, 75, 32)   36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 75, 75, 224)  0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, 75, 75, 224)  896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, 75, 75, 224)  0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 75, 75, 128)  28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, 75, 75, 128)  512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 75, 75, 128)  0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 75, 75, 32)   36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 75, 75, 256)  0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 75, 75, 256)  1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 75, 75, 256)  0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 75, 75, 128)  32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 37, 37, 128)  0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 37, 37, 128)  512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, 37, 37, 128)  0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 37, 37, 128)  16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 37, 37, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 37, 37, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 37, 37, 32)   36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 37, 37, 160)  0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, 37, 37, 160)  640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, 37, 37, 160)  0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 37, 37, 128)  20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 37, 37, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 37, 37, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 37, 37, 32)   36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 37, 37, 192)  0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, 37, 37, 192)  768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, 37, 37, 192)  0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 37, 37, 128)  24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 37, 37, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 37, 37, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 37, 37, 32)   36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 37, 37, 224)  0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, 37, 37, 224)  896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, 37, 37, 224)  0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 37, 37, 128)  28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 37, 37, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 37, 37, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 37, 37, 32)   36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 37, 37, 256)  0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, 37, 37, 256)  1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, 37, 37, 256)  0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 37, 37, 128)  32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 37, 37, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 37, 37, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 37, 37, 32)   36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 37, 37, 288)  0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, 37, 37, 288)  1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, 37, 37, 288)  0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 37, 37, 128)  36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 37, 37, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 37, 37, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 37, 37, 32)   36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 37, 37, 320)  0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, 37, 37, 320)  1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, 37, 37, 320)  0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 37, 37, 128)  40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 37, 37, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 37, 37, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 37, 37, 32)   36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 37, 37, 352)  0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, 37, 37, 352)  1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, 37, 37, 352)  0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 37, 37, 128)  45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 37, 37, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 37, 37, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 37, 37, 32)   36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 37, 37, 384)  0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, 37, 37, 384)  1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, 37, 37, 384)  0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 37, 37, 128)  49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, 37, 37, 128)  512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 37, 37, 128)  0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 37, 37, 32)   36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 37, 37, 416)  0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, 37, 37, 416)  1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, 37, 37, 416)  0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 37, 37, 128)  53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, 37, 37, 128)  512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 37, 37, 128)  0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 37, 37, 32)   36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 37, 37, 448)  0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, 37, 37, 448)  1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, 37, 37, 448)  0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 37, 37, 128)  57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, 37, 37, 128)  512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 37, 37, 128)  0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 37, 37, 32)   36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 37, 37, 480)  0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, 37, 37, 480)  1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, 37, 37, 480)  0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 37, 37, 128)  61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, 37, 37, 128)  512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 37, 37, 128)  0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 37, 37, 32)   36864       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, 37, 37, 512)  0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, 37, 37, 512)  2048        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, 37, 37, 512)  0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, 37, 37, 256)  131072      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, 18, 18, 256)  0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 18, 18, 256)  1024        pool3_pool[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_relu (Activation (None, 18, 18, 256)  0           conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 18, 18, 128)  32768       conv4_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 18, 18, 128)  512         conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 18, 18, 128)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 18, 18, 32)   36864       conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_concat (Concatenat (None, 18, 18, 288)  0           pool3_pool[0][0]
#                                                                  conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_bn (BatchNormali (None, 18, 18, 288)  1152        conv4_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_relu (Activation (None, 18, 18, 288)  0           conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 18, 18, 128)  36864       conv4_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 18, 18, 128)  512         conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 18, 18, 128)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 18, 18, 32)   36864       conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_concat (Concatenat (None, 18, 18, 320)  0           conv4_block1_concat[0][0]
#                                                                  conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_bn (BatchNormali (None, 18, 18, 320)  1280        conv4_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_relu (Activation (None, 18, 18, 320)  0           conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 18, 18, 128)  40960       conv4_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 18, 18, 128)  512         conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 18, 18, 128)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 18, 18, 32)   36864       conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_concat (Concatenat (None, 18, 18, 352)  0           conv4_block2_concat[0][0]
#                                                                  conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_bn (BatchNormali (None, 18, 18, 352)  1408        conv4_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_relu (Activation (None, 18, 18, 352)  0           conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 18, 18, 128)  45056       conv4_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 18, 18, 128)  512         conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 18, 18, 128)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 18, 18, 32)   36864       conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_concat (Concatenat (None, 18, 18, 384)  0           conv4_block3_concat[0][0]
#                                                                  conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_bn (BatchNormali (None, 18, 18, 384)  1536        conv4_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_relu (Activation (None, 18, 18, 384)  0           conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 18, 18, 128)  49152       conv4_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 18, 18, 128)  512         conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 18, 18, 128)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 18, 18, 32)   36864       conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_concat (Concatenat (None, 18, 18, 416)  0           conv4_block4_concat[0][0]
#                                                                  conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_bn (BatchNormali (None, 18, 18, 416)  1664        conv4_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_relu (Activation (None, 18, 18, 416)  0           conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 18, 18, 128)  53248       conv4_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 18, 18, 128)  512         conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 18, 18, 128)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 18, 18, 32)   36864       conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_concat (Concatenat (None, 18, 18, 448)  0           conv4_block5_concat[0][0]
#                                                                  conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_bn (BatchNormali (None, 18, 18, 448)  1792        conv4_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_relu (Activation (None, 18, 18, 448)  0           conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 18, 18, 128)  57344       conv4_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 18, 18, 128)  512         conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 18, 18, 128)  0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 18, 18, 32)   36864       conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_concat (Concatenat (None, 18, 18, 480)  0           conv4_block6_concat[0][0]
#                                                                  conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_bn (BatchNormali (None, 18, 18, 480)  1920        conv4_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_relu (Activation (None, 18, 18, 480)  0           conv4_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 18, 18, 128)  61440       conv4_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 18, 18, 128)  512         conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 18, 18, 128)  0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 18, 18, 32)   36864       conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_concat (Concatenat (None, 18, 18, 512)  0           conv4_block7_concat[0][0]
#                                                                  conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_bn (BatchNormali (None, 18, 18, 512)  2048        conv4_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_relu (Activation (None, 18, 18, 512)  0           conv4_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 18, 18, 128)  65536       conv4_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 18, 18, 128)  512         conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 18, 18, 128)  0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 18, 18, 32)   36864       conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_concat (Concatenat (None, 18, 18, 544)  0           conv4_block8_concat[0][0]
#                                                                  conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_bn (BatchNormal (None, 18, 18, 544)  2176        conv4_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_relu (Activatio (None, 18, 18, 544)  0           conv4_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 18, 18, 128)  69632       conv4_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 18, 18, 128)  512         conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 18, 18, 128)  0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 18, 18, 32)   36864       conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_concat (Concatena (None, 18, 18, 576)  0           conv4_block9_concat[0][0]
#                                                                  conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_bn (BatchNormal (None, 18, 18, 576)  2304        conv4_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_relu (Activatio (None, 18, 18, 576)  0           conv4_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 18, 18, 128)  73728       conv4_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 18, 18, 128)  512         conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 18, 18, 128)  0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 18, 18, 32)   36864       conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_concat (Concatena (None, 18, 18, 608)  0           conv4_block10_concat[0][0]
#                                                                  conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_bn (BatchNormal (None, 18, 18, 608)  2432        conv4_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_relu (Activatio (None, 18, 18, 608)  0           conv4_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 18, 18, 128)  77824       conv4_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 18, 18, 128)  512         conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 18, 18, 128)  0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 18, 18, 32)   36864       conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_concat (Concatena (None, 18, 18, 640)  0           conv4_block11_concat[0][0]
#                                                                  conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_0_bn (BatchNormal (None, 18, 18, 640)  2560        conv4_block12_concat[0][0]
# ...
# conv5_block22_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block22_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block22_concat (Concatena (None, 9, 9, 1344)   0           conv5_block21_concat[0][0]
#                                                                  conv5_block22_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block23_0_bn (BatchNormal (None, 9, 9, 1344)   5376        conv5_block22_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block23_0_relu (Activatio (None, 9, 9, 1344)   0           conv5_block23_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_conv (Conv2D)   (None, 9, 9, 128)    172032      conv5_block23_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_bn (BatchNormal (None, 9, 9, 128)    512         conv5_block23_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block23_1_relu (Activatio (None, 9, 9, 128)    0           conv5_block23_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block23_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block23_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block23_concat (Concatena (None, 9, 9, 1376)   0           conv5_block22_concat[0][0]
#                                                                  conv5_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_bn (BatchNormal (None, 9, 9, 1376)   5504        conv5_block23_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_relu (Activatio (None, 9, 9, 1376)   0           conv5_block24_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_conv (Conv2D)   (None, 9, 9, 128)    176128      conv5_block24_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_bn (BatchNormal (None, 9, 9, 128)    512         conv5_block24_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_relu (Activatio (None, 9, 9, 128)    0           conv5_block24_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block24_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_concat (Concatena (None, 9, 9, 1408)   0           conv5_block23_concat[0][0]
#                                                                  conv5_block24_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_bn (BatchNormal (None, 9, 9, 1408)   5632        conv5_block24_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_relu (Activatio (None, 9, 9, 1408)   0           conv5_block25_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_conv (Conv2D)   (None, 9, 9, 128)    180224      conv5_block25_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_bn (BatchNormal (None, 9, 9, 128)    512         conv5_block25_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_relu (Activatio (None, 9, 9, 128)    0           conv5_block25_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block25_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_concat (Concatena (None, 9, 9, 1440)   0           conv5_block24_concat[0][0]
#                                                                  conv5_block25_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_bn (BatchNormal (None, 9, 9, 1440)   5760        conv5_block25_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_relu (Activatio (None, 9, 9, 1440)   0           conv5_block26_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_conv (Conv2D)   (None, 9, 9, 128)    184320      conv5_block26_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_bn (BatchNormal (None, 9, 9, 128)    512         conv5_block26_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_relu (Activatio (None, 9, 9, 128)    0           conv5_block26_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block26_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_concat (Concatena (None, 9, 9, 1472)   0           conv5_block25_concat[0][0]
#                                                                  conv5_block26_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_bn (BatchNormal (None, 9, 9, 1472)   5888        conv5_block26_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_relu (Activatio (None, 9, 9, 1472)   0           conv5_block27_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_conv (Conv2D)   (None, 9, 9, 128)    188416      conv5_block27_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_bn (BatchNormal (None, 9, 9, 128)    512         conv5_block27_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_relu (Activatio (None, 9, 9, 128)    0           conv5_block27_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block27_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_concat (Concatena (None, 9, 9, 1504)   0           conv5_block26_concat[0][0]
#                                                                  conv5_block27_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_bn (BatchNormal (None, 9, 9, 1504)   6016        conv5_block27_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_relu (Activatio (None, 9, 9, 1504)   0           conv5_block28_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_conv (Conv2D)   (None, 9, 9, 128)    192512      conv5_block28_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_bn (BatchNormal (None, 9, 9, 128)    512         conv5_block28_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_relu (Activatio (None, 9, 9, 128)    0           conv5_block28_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block28_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_concat (Concatena (None, 9, 9, 1536)   0           conv5_block27_concat[0][0]
#                                                                  conv5_block28_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_bn (BatchNormal (None, 9, 9, 1536)   6144        conv5_block28_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_relu (Activatio (None, 9, 9, 1536)   0           conv5_block29_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_conv (Conv2D)   (None, 9, 9, 128)    196608      conv5_block29_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_bn (BatchNormal (None, 9, 9, 128)    512         conv5_block29_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_relu (Activatio (None, 9, 9, 128)    0           conv5_block29_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block29_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_concat (Concatena (None, 9, 9, 1568)   0           conv5_block28_concat[0][0]
#                                                                  conv5_block29_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_bn (BatchNormal (None, 9, 9, 1568)   6272        conv5_block29_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_relu (Activatio (None, 9, 9, 1568)   0           conv5_block30_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_conv (Conv2D)   (None, 9, 9, 128)    200704      conv5_block30_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_bn (BatchNormal (None, 9, 9, 128)    512         conv5_block30_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_relu (Activatio (None, 9, 9, 128)    0           conv5_block30_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block30_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_concat (Concatena (None, 9, 9, 1600)   0           conv5_block29_concat[0][0]
#                                                                  conv5_block30_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_bn (BatchNormal (None, 9, 9, 1600)   6400        conv5_block30_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_relu (Activatio (None, 9, 9, 1600)   0           conv5_block31_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_conv (Conv2D)   (None, 9, 9, 128)    204800      conv5_block31_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_bn (BatchNormal (None, 9, 9, 128)    512         conv5_block31_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_relu (Activatio (None, 9, 9, 128)    0           conv5_block31_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block31_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_concat (Concatena (None, 9, 9, 1632)   0           conv5_block30_concat[0][0]
#                                                                  conv5_block31_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_bn (BatchNormal (None, 9, 9, 1632)   6528        conv5_block31_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_relu (Activatio (None, 9, 9, 1632)   0           conv5_block32_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_conv (Conv2D)   (None, 9, 9, 128)    208896      conv5_block32_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_bn (BatchNormal (None, 9, 9, 128)    512         conv5_block32_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_relu (Activatio (None, 9, 9, 128)    0           conv5_block32_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block32_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_concat (Concatena (None, 9, 9, 1664)   0           conv5_block31_concat[0][0]
#                                                                  conv5_block32_2_conv[0][0]
# __________________________________________________________________________________________________
# bn (BatchNormalization)         (None, 9, 9, 1664)   6656        conv5_block32_concat[0][0]
# __________________________________________________________________________________________________
# relu (Activation)               (None, 9, 9, 1664)   0           bn[0][0]
# ==================================================================================================
# Total params: 12,642,880
# Trainable params: 0
# Non-trainable params: 12,642,880
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau , ModelCheckpoint
lr_reduce = ReduceLROnPlateau(monitor='val_acc', factor=0.1, epsilon=0.0001, patience=1, verbose=1)

filepath="transferlearning_weights.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
from tensorflow.keras import Model
x = tf.keras.layers.Flatten()(pre_trained_model.output)
#Full Connected Layers
x = tf.keras.layers.Dense(512, activation='relu')(x)
#Add dropout to avoid Overfit
x = tf.keras.layers.Dropout(0.2)(x)
x = tf.keras.layers.Dense(256, activation='relu')(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
#Add dropout to avoid Overfit
x = tf.keras.layers.Dropout(0.4)(x)
x = tf.keras.layers.Dense(64, activation='relu')(x)
x=tf.keras.layers.Dense(3 , activation='sigmoid')(x)   
model = Model( pre_trained_model.input, x)

# %%
model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])
reduction_lr = ReduceLROnPlateau(monitor = "val_accuracy",patience = 2 ,verbose = 1, factor = 0.2, min_lr = 0.00001)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 306, 306, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 150, 150, 64) 9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 150, 150, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 150, 150, 64) 0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 152, 152, 64) 0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 75, 75, 64)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 75, 75, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, 75, 75, 64)   0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 75, 75, 128)  8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 75, 75, 128)  512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 75, 75, 128)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 75, 75, 32)   36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 75, 75, 96)   0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, 75, 75, 96)   384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, 75, 75, 96)   0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 75, 75, 128)  12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 75, 75, 128)  512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 75, 75, 128)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 75, 75, 32)   36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 75, 75, 128)  0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, 75, 75, 128)  512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, 75, 75, 128)  0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 75, 75, 128)  16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 75, 75, 128)  512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 75, 75, 128)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 75, 75, 32)   36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 75, 75, 160)  0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, 75, 75, 160)  640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, 75, 75, 160)  0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 75, 75, 128)  20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 75, 75, 128)  512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 75, 75, 128)  0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 75, 75, 32)   36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 75, 75, 192)  0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, 75, 75, 192)  768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, 75, 75, 192)  0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 75, 75, 128)  24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, 75, 75, 128)  512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 75, 75, 128)  0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 75, 75, 32)   36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 75, 75, 224)  0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, 75, 75, 224)  896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, 75, 75, 224)  0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 75, 75, 128)  28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, 75, 75, 128)  512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 75, 75, 128)  0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 75, 75, 32)   36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 75, 75, 256)  0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 75, 75, 256)  1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 75, 75, 256)  0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 75, 75, 128)  32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 37, 37, 128)  0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 37, 37, 128)  512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, 37, 37, 128)  0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 37, 37, 128)  16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 37, 37, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 37, 37, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 37, 37, 32)   36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 37, 37, 160)  0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, 37, 37, 160)  640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, 37, 37, 160)  0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 37, 37, 128)  20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 37, 37, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 37, 37, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 37, 37, 32)   36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 37, 37, 192)  0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, 37, 37, 192)  768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, 37, 37, 192)  0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 37, 37, 128)  24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 37, 37, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 37, 37, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 37, 37, 32)   36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 37, 37, 224)  0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, 37, 37, 224)  896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, 37, 37, 224)  0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 37, 37, 128)  28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 37, 37, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 37, 37, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 37, 37, 32)   36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 37, 37, 256)  0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, 37, 37, 256)  1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, 37, 37, 256)  0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 37, 37, 128)  32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 37, 37, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 37, 37, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 37, 37, 32)   36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 37, 37, 288)  0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, 37, 37, 288)  1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, 37, 37, 288)  0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 37, 37, 128)  36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 37, 37, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 37, 37, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 37, 37, 32)   36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 37, 37, 320)  0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, 37, 37, 320)  1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, 37, 37, 320)  0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 37, 37, 128)  40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 37, 37, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 37, 37, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 37, 37, 32)   36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 37, 37, 352)  0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, 37, 37, 352)  1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, 37, 37, 352)  0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 37, 37, 128)  45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 37, 37, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 37, 37, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 37, 37, 32)   36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 37, 37, 384)  0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, 37, 37, 384)  1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, 37, 37, 384)  0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 37, 37, 128)  49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, 37, 37, 128)  512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 37, 37, 128)  0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 37, 37, 32)   36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 37, 37, 416)  0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, 37, 37, 416)  1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, 37, 37, 416)  0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 37, 37, 128)  53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, 37, 37, 128)  512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 37, 37, 128)  0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 37, 37, 32)   36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 37, 37, 448)  0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, 37, 37, 448)  1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, 37, 37, 448)  0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 37, 37, 128)  57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, 37, 37, 128)  512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 37, 37, 128)  0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 37, 37, 32)   36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 37, 37, 480)  0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, 37, 37, 480)  1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, 37, 37, 480)  0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 37, 37, 128)  61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, 37, 37, 128)  512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 37, 37, 128)  0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 37, 37, 32)   36864       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, 37, 37, 512)  0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, 37, 37, 512)  2048        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, 37, 37, 512)  0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, 37, 37, 256)  131072      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, 18, 18, 256)  0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 18, 18, 256)  1024        pool3_pool[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_relu (Activation (None, 18, 18, 256)  0           conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 18, 18, 128)  32768       conv4_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 18, 18, 128)  512         conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 18, 18, 128)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 18, 18, 32)   36864       conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_concat (Concatenat (None, 18, 18, 288)  0           pool3_pool[0][0]
#                                                                  conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_bn (BatchNormali (None, 18, 18, 288)  1152        conv4_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_relu (Activation (None, 18, 18, 288)  0           conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 18, 18, 128)  36864       conv4_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 18, 18, 128)  512         conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 18, 18, 128)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 18, 18, 32)   36864       conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_concat (Concatenat (None, 18, 18, 320)  0           conv4_block1_concat[0][0]
#                                                                  conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_bn (BatchNormali (None, 18, 18, 320)  1280        conv4_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_relu (Activation (None, 18, 18, 320)  0           conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 18, 18, 128)  40960       conv4_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 18, 18, 128)  512         conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 18, 18, 128)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 18, 18, 32)   36864       conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_concat (Concatenat (None, 18, 18, 352)  0           conv4_block2_concat[0][0]
#                                                                  conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_bn (BatchNormali (None, 18, 18, 352)  1408        conv4_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_relu (Activation (None, 18, 18, 352)  0           conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 18, 18, 128)  45056       conv4_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 18, 18, 128)  512         conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 18, 18, 128)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 18, 18, 32)   36864       conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_concat (Concatenat (None, 18, 18, 384)  0           conv4_block3_concat[0][0]
#                                                                  conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_bn (BatchNormali (None, 18, 18, 384)  1536        conv4_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_relu (Activation (None, 18, 18, 384)  0           conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 18, 18, 128)  49152       conv4_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 18, 18, 128)  512         conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 18, 18, 128)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 18, 18, 32)   36864       conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_concat (Concatenat (None, 18, 18, 416)  0           conv4_block4_concat[0][0]
#                                                                  conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_bn (BatchNormali (None, 18, 18, 416)  1664        conv4_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_relu (Activation (None, 18, 18, 416)  0           conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 18, 18, 128)  53248       conv4_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 18, 18, 128)  512         conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 18, 18, 128)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 18, 18, 32)   36864       conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_concat (Concatenat (None, 18, 18, 448)  0           conv4_block5_concat[0][0]
#                                                                  conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_bn (BatchNormali (None, 18, 18, 448)  1792        conv4_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_relu (Activation (None, 18, 18, 448)  0           conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 18, 18, 128)  57344       conv4_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 18, 18, 128)  512         conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 18, 18, 128)  0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 18, 18, 32)   36864       conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_concat (Concatenat (None, 18, 18, 480)  0           conv4_block6_concat[0][0]
#                                                                  conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_bn (BatchNormali (None, 18, 18, 480)  1920        conv4_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_relu (Activation (None, 18, 18, 480)  0           conv4_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 18, 18, 128)  61440       conv4_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 18, 18, 128)  512         conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 18, 18, 128)  0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 18, 18, 32)   36864       conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_concat (Concatenat (None, 18, 18, 512)  0           conv4_block7_concat[0][0]
#                                                                  conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_bn (BatchNormali (None, 18, 18, 512)  2048        conv4_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_relu (Activation (None, 18, 18, 512)  0           conv4_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 18, 18, 128)  65536       conv4_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 18, 18, 128)  512         conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 18, 18, 128)  0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 18, 18, 32)   36864       conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_concat (Concatenat (None, 18, 18, 544)  0           conv4_block8_concat[0][0]
#                                                                  conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_bn (BatchNormal (None, 18, 18, 544)  2176        conv4_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_relu (Activatio (None, 18, 18, 544)  0           conv4_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 18, 18, 128)  69632       conv4_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 18, 18, 128)  512         conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 18, 18, 128)  0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 18, 18, 32)   36864       conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_concat (Concatena (None, 18, 18, 576)  0           conv4_block9_concat[0][0]
#                                                                  conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_bn (BatchNormal (None, 18, 18, 576)  2304        conv4_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_relu (Activatio (None, 18, 18, 576)  0           conv4_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 18, 18, 128)  73728       conv4_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 18, 18, 128)  512         conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 18, 18, 128)  0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 18, 18, 32)   36864       conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_concat (Concatena (None, 18, 18, 608)  0           conv4_block10_concat[0][0]
#                                                                  conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_bn (BatchNormal (None, 18, 18, 608)  2432        conv4_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_relu (Activatio (None, 18, 18, 608)  0           conv4_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 18, 18, 128)  77824       conv4_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 18, 18, 128)  512         conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 18, 18, 128)  0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 18, 18, 32)   36864       conv4_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_concat (Concatena (None, 18, 18, 640)  0           conv4_block11_concat[0][0]
#                                                                  conv4_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block13_0_bn (BatchNormal (None, 18, 18, 640)  2560        conv4_block12_concat[0][0]
# ...
# __________________________________________________________________________________________________
# conv5_block23_concat (Concatena (None, 9, 9, 1376)   0           conv5_block22_concat[0][0]
#                                                                  conv5_block23_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_bn (BatchNormal (None, 9, 9, 1376)   5504        conv5_block23_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block24_0_relu (Activatio (None, 9, 9, 1376)   0           conv5_block24_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_conv (Conv2D)   (None, 9, 9, 128)    176128      conv5_block24_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_bn (BatchNormal (None, 9, 9, 128)    512         conv5_block24_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block24_1_relu (Activatio (None, 9, 9, 128)    0           conv5_block24_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block24_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block24_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block24_concat (Concatena (None, 9, 9, 1408)   0           conv5_block23_concat[0][0]
#                                                                  conv5_block24_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_bn (BatchNormal (None, 9, 9, 1408)   5632        conv5_block24_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block25_0_relu (Activatio (None, 9, 9, 1408)   0           conv5_block25_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_conv (Conv2D)   (None, 9, 9, 128)    180224      conv5_block25_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_bn (BatchNormal (None, 9, 9, 128)    512         conv5_block25_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block25_1_relu (Activatio (None, 9, 9, 128)    0           conv5_block25_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block25_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block25_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block25_concat (Concatena (None, 9, 9, 1440)   0           conv5_block24_concat[0][0]
#                                                                  conv5_block25_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_bn (BatchNormal (None, 9, 9, 1440)   5760        conv5_block25_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block26_0_relu (Activatio (None, 9, 9, 1440)   0           conv5_block26_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_conv (Conv2D)   (None, 9, 9, 128)    184320      conv5_block26_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_bn (BatchNormal (None, 9, 9, 128)    512         conv5_block26_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block26_1_relu (Activatio (None, 9, 9, 128)    0           conv5_block26_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block26_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block26_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block26_concat (Concatena (None, 9, 9, 1472)   0           conv5_block25_concat[0][0]
#                                                                  conv5_block26_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_bn (BatchNormal (None, 9, 9, 1472)   5888        conv5_block26_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block27_0_relu (Activatio (None, 9, 9, 1472)   0           conv5_block27_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_conv (Conv2D)   (None, 9, 9, 128)    188416      conv5_block27_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_bn (BatchNormal (None, 9, 9, 128)    512         conv5_block27_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block27_1_relu (Activatio (None, 9, 9, 128)    0           conv5_block27_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block27_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block27_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block27_concat (Concatena (None, 9, 9, 1504)   0           conv5_block26_concat[0][0]
#                                                                  conv5_block27_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_bn (BatchNormal (None, 9, 9, 1504)   6016        conv5_block27_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block28_0_relu (Activatio (None, 9, 9, 1504)   0           conv5_block28_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_conv (Conv2D)   (None, 9, 9, 128)    192512      conv5_block28_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_bn (BatchNormal (None, 9, 9, 128)    512         conv5_block28_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block28_1_relu (Activatio (None, 9, 9, 128)    0           conv5_block28_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block28_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block28_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block28_concat (Concatena (None, 9, 9, 1536)   0           conv5_block27_concat[0][0]
#                                                                  conv5_block28_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_bn (BatchNormal (None, 9, 9, 1536)   6144        conv5_block28_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block29_0_relu (Activatio (None, 9, 9, 1536)   0           conv5_block29_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_conv (Conv2D)   (None, 9, 9, 128)    196608      conv5_block29_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_bn (BatchNormal (None, 9, 9, 128)    512         conv5_block29_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block29_1_relu (Activatio (None, 9, 9, 128)    0           conv5_block29_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block29_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block29_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block29_concat (Concatena (None, 9, 9, 1568)   0           conv5_block28_concat[0][0]
#                                                                  conv5_block29_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_bn (BatchNormal (None, 9, 9, 1568)   6272        conv5_block29_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block30_0_relu (Activatio (None, 9, 9, 1568)   0           conv5_block30_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_conv (Conv2D)   (None, 9, 9, 128)    200704      conv5_block30_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_bn (BatchNormal (None, 9, 9, 128)    512         conv5_block30_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block30_1_relu (Activatio (None, 9, 9, 128)    0           conv5_block30_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block30_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block30_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block30_concat (Concatena (None, 9, 9, 1600)   0           conv5_block29_concat[0][0]
#                                                                  conv5_block30_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_bn (BatchNormal (None, 9, 9, 1600)   6400        conv5_block30_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_relu (Activatio (None, 9, 9, 1600)   0           conv5_block31_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_conv (Conv2D)   (None, 9, 9, 128)    204800      conv5_block31_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_bn (BatchNormal (None, 9, 9, 128)    512         conv5_block31_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_relu (Activatio (None, 9, 9, 128)    0           conv5_block31_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block31_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_concat (Concatena (None, 9, 9, 1632)   0           conv5_block30_concat[0][0]
#                                                                  conv5_block31_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_bn (BatchNormal (None, 9, 9, 1632)   6528        conv5_block31_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_relu (Activatio (None, 9, 9, 1632)   0           conv5_block32_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_conv (Conv2D)   (None, 9, 9, 128)    208896      conv5_block32_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_bn (BatchNormal (None, 9, 9, 128)    512         conv5_block32_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_relu (Activatio (None, 9, 9, 128)    0           conv5_block32_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_2_conv (Conv2D)   (None, 9, 9, 32)     36864       conv5_block32_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_concat (Concatena (None, 9, 9, 1664)   0           conv5_block31_concat[0][0]
#                                                                  conv5_block32_2_conv[0][0]
# __________________________________________________________________________________________________
# bn (BatchNormalization)         (None, 9, 9, 1664)   6656        conv5_block32_concat[0][0]
# __________________________________________________________________________________________________
# relu (Activation)               (None, 9, 9, 1664)   0           bn[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 134784)       0           relu[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          69009920    flatten[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          131328      dropout[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          32896       dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           8256        dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 3)            195         dense_3[0][0]
# ==================================================================================================
# Total params: 81,825,475
# Trainable params: 69,182,595
# Non-trainable params: 12,642,880
# __________________________________________________________________________________________________

# %%
callback_list = [reduction_lr]

# %% [markdown]
# Model Training with 30 Epochs

# %%
history = model.fit_generator(train_generator,steps_per_epoch=1,callbacks = callback_list,epochs=30)
# Out:
# Epoch 1/30
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-44-587ddee4840e> in <module>()
# ----> 1 history = model.fit_generator(train_generator,steps_per_epoch=1,callbacks = callback_list,epochs=30)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1295         shuffle=shuffle,
#    1296         initial_epoch=initial_epoch,
# -> 1297         steps_name='steps_per_epoch')
#    1298
#    1299   def evaluate_generator(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     263
#     264       is_deferred = not model._is_compiled
# --> 265       batch_outs = batch_function(*batch_data)
#     266       if not isinstance(batch_outs, list):
#     267         batch_outs = [batch_outs]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#     971       outputs = training_v2_utils.train_on_batch(
#     972           self, x, y=y, sample_weight=sample_weight,
# --> 973           class_weight=class_weight, reset_metrics=reset_metrics)
#     974       outputs = (outputs['total_loss'] + outputs['output_losses'] +
#     975                  outputs['metrics'])
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_v2_utils.py in train_on_batch(model, x, y, sample_weight, class_weight, reset_metrics)
#     262       y,
#     263       sample_weights=sample_weights,
# --> 264       output_loss_metrics=model._output_loss_metrics)
#     265
#     266   if reset_metrics:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_eager.py in train_on_batch(model, inputs, targets, sample_weights, output_loss_metrics)
#     309           sample_weights=sample_weights,
#     310           training=True,
# --> 311           output_loss_metrics=output_loss_metrics))
#     312   if not isinstance(outs, list):
#     313     outs = [outs]
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_eager.py in _process_single_batch(model, inputs, targets, output_loss_metrics, sample_weights, training)
#     250               output_loss_metrics=output_loss_metrics,
#     251               sample_weights=sample_weights,
# --> 252               training=training))
#     253       if total_loss is None:
#     254         raise ValueError('The model cannot be run '
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_eager.py in _model_loss(model, inputs, targets, output_loss_metrics, sample_weights, training)
#     125     inputs = nest.map_structure(ops.convert_to_tensor, inputs)
#     126
# --> 127   outs = model(inputs, **kwargs)
#     128   outs = nest.flatten(outs)
#     129
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
# --> 891             outputs = self.call(cast_inputs, *args, **kwargs)
#     892           self._handle_activity_regularization(inputs, outputs)
#     893           self._set_mask_metadata(inputs, outputs, input_masks)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/network.py in call(self, inputs, training, mask)
#     706     return self._run_internal_graph(
#     707         inputs, training=training, mask=mask,
# --> 708         convert_kwargs_to_constants=base_layer_utils.call_context().saving)
#     709
#     710   def compute_output_shape(self, input_shape):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/network.py in _run_internal_graph(self, inputs, training, mask, convert_kwargs_to_constants)
#     858
#     859           # Compute outputs.
# --> 860           output_tensors = layer(computed_tensors, **kwargs)
#     861
#     862           # Update tensor_dict.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     889           with base_layer_utils.autocast_context_manager(
#     890               self._compute_dtype):
# --> 891             outputs = self.call(cast_inputs, *args, **kwargs)
#     892           self._handle_activity_regularization(inputs, outputs)
#     893           self._set_mask_metadata(inputs, outputs, input_masks)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/layers/normalization.py in call(self, inputs, training)
#     657
#     658     if self.fused:
# --> 659       outputs = self._fused_batch_norm(inputs, training=training)
#     660       if self.virtual_batch_size is not None:
#     661         # Currently never reaches here since fused_batch_norm does not support
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/layers/normalization.py in _fused_batch_norm(self, inputs, training)
#     515
#     516     output, mean, variance = tf_utils.smart_cond(
# --> 517         training, _fused_batch_norm_training, _fused_batch_norm_inference)
#     518     if not self._bessels_correction_test_only:
#     519       # Remove Bessel's correction to be consistent with non-fused batch norm.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/utils/tf_utils.py in smart_cond(pred, true_fn, false_fn, name)
#      57         pred, true_fn=true_fn, false_fn=false_fn, name=name)
#      58   return smart_module.smart_cond(
# ---> 59       pred, true_fn=true_fn, false_fn=false_fn, name=name)
#      60
#      61
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/smart_cond.py in smart_cond(pred, true_fn, false_fn, name)
#      52   if pred_value is not None:
#      53     if pred_value:
# ---> 54       return true_fn()
#      55     else:
#      56       return false_fn()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/layers/normalization.py in _fused_batch_norm_training()
#     501           beta,
#     502           epsilon=self.epsilon,
# --> 503           data_format=self._data_format)
#     504
#     505     def _fused_batch_norm_inference():
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py in fused_batch_norm(x, scale, offset, mean, variance, epsilon, data_format, is_training, name)
#    1507         data_format=data_format,
#    1508         is_training=is_training,
# -> 1509         name=name)
#    1510     return y, batch_mean, batch_var
#    1511
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/gen_nn_ops.py in fused_batch_norm_v3(x, scale, offset, mean, variance, epsilon, data_format, is_training, name)
#    4603       else:
#    4604         message = e.message
# -> 4605       _six.raise_from(_core._status_to_exception(e.code, message), None)
#    4606   # Add nodes to the TensorFlow graph.
#    4607   if epsilon is None:
#
# /usr/local/lib/python3.6/dist-packages/six.py in raise_from(value, from_value)
#
# ResourceExhaustedError: OOM when allocating tensor with shape[47,800,18,18] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:FusedBatchNormV3]

# %% [markdown]
# # Accuracy for DesNet Model

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-217581b9d57d> in <module>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.plot(history.history['accuracy'])
#       4 plt.title('model accuracy')
#       5 plt.ylabel('accuracy')
#
# NameError: name 'history' is not defined

# %%
#Evaluate Model
val1 = model.evaluate(test_generator, batch_size=1)

# %%
Desnet_ACC = val1[1]

# %% [markdown]
# # COVNet with CNN-2D

# %% [markdown]
# Importing Packages

# %%
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.layers import Dropout, MaxPooling2D, AveragePooling2D, Dense, Flatten, Input, Conv2D, add, Activation
from tensorflow.keras.layers import (Dense, Dropout, Activation, Flatten, Reshape, Layer, BatchNormalization, LocallyConnected2D, ZeroPadding2D, Conv2D, MaxPooling2D, Conv2DTranspose,AveragePooling2D, GaussianNoise, UpSampling2D, Input)
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Sequential , Model , load_model
from tensorflow.keras.preprocessing.image import load_img , img_to_array , ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras import applications
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report, confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

import time
import numpy as np
import warnings
import matplotlib.pyplot as plt
from PIL import Image
import os
import pandas as pd
from skimage import io
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Data Exploration

# %%
train_dir = '/content/drive/MyDrive/covid/Data_test/train'
test_dir = '/content/drive/MyDrive/covid/Data_test/test'

image_size = 224

# %% [markdown]
# Feature Extraction

# %%
batch_size = 32

train_datagen = ImageDataGenerator(rescale = 1./255,
                            rotation_range=45,
                            zoom_range=0.40,
                            width_shift_range=0.2,
                            height_shift_range=0.2,
                            shear_range=0.15,
                            horizontal_flip=True,
                            vertical_flip= True,
                            fill_mode="nearest")

train_data = train_datagen.flow_from_directory(train_dir,
                                              target_size=(150,150),
                                              batch_size=32,
                                              class_mode="categorical")
# Out:
# Found 47 images belonging to 3 classes.

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_data = test_datagen.flow_from_directory(test_dir,
                                            target_size=(150,150),
                                            batch_size=32,
                                            class_mode="categorical")
# Out:
# Found 47 images belonging to 3 classes.

# %% [markdown]
# Model Building

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/compat/v2_compat.py:65: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
#=================================================================
chanDim = 1
model = Sequential(name="COVNet")
model.add(Conv2D(32, (3, 3), padding="same",input_shape=(150,150,3)))
model.add(Activation("relu"))

model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (4, 4), padding="same"))
model.add(Activation("relu"))

model.add(Conv2D(64, (4, 4), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (4, 4), padding="same"))
model.add(Activation("relu"))

model.add(Conv2D(128, (4, 4), padding="same"))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(1024))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(3))
model.add(Activation("softmax"))


model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])
reduction_lr = ReduceLROnPlateau(monitor = "val_accuracy",patience = 2 ,verbose = 1, factor = 0.2, min_lr = 0.00001)
model.summary()
plot_model(model,show_shapes=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "COVNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 150, 150, 32)      896
# _________________________________________________________________
# activation_5 (Activation)    (None, 150, 150, 32)      0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 50, 50, 32)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 50, 50, 64)        32832
# _________________________________________________________________
# activation_6 (Activation)    (None, 50, 50, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 50, 50, 64)        65600
# _________________________________________________________________
# activation_7 (Activation)    (None, 50, 50, 64)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 25, 25, 64)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 25, 25, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 25, 25, 128)       131200
# _________________________________________________________________
# activation_8 (Activation)    (None, 25, 25, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 25, 25, 128)       262272
# _________________________________________________________________
# activation_9 (Activation)    (None, 25, 25, 128)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              18875392
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 3075
# _________________________________________________________________
# activation_10 (Activation)   (None, 3)                 0
# =================================================================
# Total params: 19,375,363
# Trainable params: 19,373,315
# Non-trainable params: 2,048
# _________________________________________________________________

# %%
callback_list = [reduction_lr]

# %% [markdown]
# Model Training

# %%
start = time.time()

history = model.fit_generator(train_data,
                    steps_per_epoch = 10,
                    validation_data = test_data,
                    validation_steps = 10,
                    epochs=30,
                    callbacks = callback_list)
end = time.time()
print("Total train time: ",(end-start)/60," mins")
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#
# ResourceExhaustedError: OOM when allocating tensor with shape[18432,1024] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node dense_6/kernel/Initializer/random_uniform/RandomUniform}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-58-ce837a4e7121> in <module>()
#       6                     validation_steps = 10,
#       7                     epochs=30,
# ----> 8                     callbacks = callback_list)
#       9 end = time.time()
#      10 print("Total train time: ",(end-start)/60," mins")
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1295         shuffle=shuffle,
#    1296         initial_epoch=initial_epoch,
# -> 1297         steps_name='steps_per_epoch')
#    1298
#    1299   def evaluate_generator(self,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training_generator.py in model_iteration(model, data, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch, mode, batch_size, steps_name, **kwargs)
#     204
#     205     # Setup work for each epoch.
# --> 206     model.reset_metrics()
#     207     epoch_logs = {}
#     208     if mode == ModeKeys.TRAIN:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/training.py in reset_metrics(self)
#     913     metrics = self._get_training_eval_metrics()
#     914     for m in metrics:
# --> 915       m.reset_states()
#     916
#     917     # Reset metrics on all the distributed (cloned) models.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/metrics.py in reset_states(self)
#     207     when a metric is evaluated during training.
#     208     """
# --> 209     K.batch_set_value([(v, 0) for v in self.variables])
#     210
#     211   @abc.abstractmethod
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/backend.py in batch_set_value(tuples)
#    3361           assign_ops.append(assign_op)
#    3362           feed_dict[assign_placeholder] = value
# -> 3363         get_session().run(assign_ops, feed_dict=feed_dict)
#    3364
#    3365
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/backend.py in get_session(op_input_list)
#     489   if not _MANUAL_VAR_INIT:
#     490     with session.graph.as_default():
# --> 491       _initialize_variables(session)
#     492   return session
#     493
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/backend.py in _initialize_variables(session)
#     913       v._keras_initialized = True
#     914     if uninitialized_vars:
# --> 915       session.run(variables_module.variables_initializer(uninitialized_vars))
#     916
#     917
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1382                     '\nsession_config.graph_options.rewrite_options.'
#    1383                     'disable_meta_optimizer = True')
# -> 1384       raise type(e)(node_def, op, message)
#    1385
#    1386   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor with shape[18432,1024] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node dense_6/kernel/Initializer/random_uniform/RandomUniform (defined at /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py:1751) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#
# Original stack trace for 'dense_6/kernel/Initializer/random_uniform/RandomUniform':
#   File "/usr/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/usr/local/lib/python3.6/dist-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelapp.py", line 499, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.6/dist-packages/tornado/platform/asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 438, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1451, in _run_once
#     handle._run()
#   File "/usr/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/platform/asyncio.py", line 122, in _handle_events
#     handler_func(fileobj, events)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 462, in _handle_events
#     self._handle_recv()
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 492, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/usr/local/lib/python3.6/dist-packages/zmq/eventloop/zmqstream.py", line 444, in _run_callback
#     callback(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tornado/stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/usr/local/lib/python3.6/dist-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2718, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2822, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py", line 2882, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-56-3132f9deb52f>", line 28, in <module>
#     model.add(Dense(1024))
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/tracking/base.py", line 457, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/sequential.py", line 196, in add
#     output_tensor = layer(self.outputs[0])
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/base_layer.py", line 817, in __call__
#     self._maybe_build(inputs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/base_layer.py", line 2141, in _maybe_build
#     self.build(input_shapes)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/layers/core.py", line 1027, in build
#     trainable=True)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/base_layer.py", line 522, in add_weight
#     aggregation=aggregation)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/tracking/base.py", line 744, in _add_variable_with_custom_getter
#     **kwargs_for_getter)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/base_layer_utils.py", line 139, in make_variable
#     shape=variable_shape if variable_shape else None)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/variables.py", line 258, in __call__
#     return cls._variable_v1_call(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/variables.py", line 219, in _variable_v1_call
#     shape=shape)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/variables.py", line 197, in <lambda>
#     previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/variable_scope.py", line 2507, in default_variable_creator
#     shape=shape)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/variables.py", line 262, in __call__
#     return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py", line 1406, in __init__
#     distribute_strategy=distribute_strategy)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py", line 1537, in _init_from_args
#     initial_value() if init_from_fn else initial_value,
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/keras/engine/base_layer_utils.py", line 119, in <lambda>
#     init_val = lambda: initializer(shape, dtype=dtype)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py", line 533, in __call__
#     shape, -limit, limit, dtype, seed=self.seed)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/random_ops.py", line 245, in random_uniform
#     rnd = gen_random_ops.random_uniform(shape, dtype, seed=seed1, seed2=seed2)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/gen_random_ops.py", line 823, in random_uniform
#     name=name)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/op_def_library.py", line 793, in _apply_op_helper
#     op_def=op_def)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 3360, in create_op
#     attrs, op_def, compute_device)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 3429, in _create_op_internal
#     op_def=op_def)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/framework/ops.py", line 1751, in __init__
#     self._traceback = tf_stack.extract_stack()

# %% [markdown]
# # Accuracy for CovNet Model

# %%
def plot_graph(history,string):
    plt.figure(figsize=(12,8))
    plt.plot(history.history[string],label=str(string))
    plt.plot(history.history["val_"+str(string)],label="val_"+str(string))
    plt.xlabel("Epochs")
    plt.ylabel(str(string))
    plt.legend()
    plt.show()
plot_graph(history,"accuracy")
plot_graph(history,"loss")

# %%
#Evaluate Model
val2 = model.evaluate(test_data, batch_size=1)

# %%
CON_ACC = val2[1]

# %% [markdown]
# # Model Saving

# %%
model.save("/content/drive/MyDrive/covid/COVNet.h5")
